# %%
import pandas as pd

# %%
#importing file from directory
file1 = pd.read_csv("E:\\2020 WPL WIDHYA\\Day 1\\deliveries.csv")
file2 = pd.read_csv("E:\\2020 WPL WIDHYA\\Day 1\\matches.csv")

# %%
#displaying data from file1
file1
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
#displaying data from file2
file2
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
#Information of dataset in file1
file1.info
# Out:
# <bound method DataFrame.info of         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
#Information of dataset in file2
file2.info
# Out:
# <bound method DataFrame.info of         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
file1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
file2.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
file1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#Categorizing fields in dataset
file1.batting_team = file1.batting_team.astype("category")

# %%
file1.bowling_team = file1.bowling_team.astype("category")

# %%
file1.batsman = file1.batsman.astype("category")
file1.bowler = file1.bowler.astype("category")
file1.non_striker = file1.non_striker.astype("category")

# %%
file1.batting_team.cat.categories
# Out:
# Index(['Chennai Super Kings', 'Deccan Chargers', 'Delhi Capitals',
#        'Delhi Daredevils', 'Gujarat Lions', 'Kings XI Punjab',
#        'Kochi Tuskers Kerala', 'Kolkata Knight Riders', 'Mumbai Indians',
#        'Pune Warriors', 'Rajasthan Royals', 'Rising Pune Supergiant',
#        'Rising Pune Supergiants', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad'],
#       dtype='object')

# %%
#Batting done by mumbai indians from deliveries.csv
file1[file1.batting_team == "Mumbai Indians"]
# Out:
#         match_id  inning    batting_team            bowling_team  over  ball  \
# 248            2       1  Mumbai Indians  Rising Pune Supergiant     1     1
# 249            2       1  Mumbai Indians  Rising Pune Supergiant     1     2
# 250            2       1  Mumbai Indians  Rising Pune Supergiant     1     3
# 251            2       1  Mumbai Indians  Rising Pune Supergiant     1     4
# 252            2       1  Mumbai Indians  Rising Pune Supergiant     1     5
# ...          ...     ...             ...                     ...   ...   ...
# 178949     11415       1  Mumbai Indians     Chennai Super Kings    20     2
# 178950     11415       1  Mumbai Indians     Chennai Super Kings    20     3
# 178951     11415       1  Mumbai Indians     Chennai Super Kings    20     4
# 178952     11415       1  Mumbai Indians     Chennai Super Kings    20     5
# 178953     11415       1  Mumbai Indians     Chennai Super Kings    20     6
#
# ...

# %%
#Batting done by delhi capitals from deliveries.csv
file1[file1.batting_team == "Delhi Capitals"]
# Out:
#         match_id  inning    batting_team         bowling_team  over  ball  \
# 165208     11139       1  Delhi Capitals       Mumbai Indians     1     1
# 165209     11139       1  Delhi Capitals       Mumbai Indians     1     2
# 165210     11139       1  Delhi Capitals       Mumbai Indians     1     3
# 165211     11139       1  Delhi Capitals       Mumbai Indians     1     4
# 165212     11139       1  Delhi Capitals       Mumbai Indians     1     5
# ...          ...     ...             ...                  ...   ...   ...
# 178709     11414       1  Delhi Capitals  Chennai Super Kings    20     2
# 178710     11414       1  Delhi Capitals  Chennai Super Kings    20     3
# 178711     11414       1  Delhi Capitals  Chennai Super Kings    20     4
# 178712     11414       1  Delhi Capitals  Chennai Super Kings    20     5
# 178713     11414       1  Delhi Capitals  Chennai Super Kings    20     6
#
#          batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# ...

# %%
#filteribg by mumbai indians in team1 as baseline
file2[file2.team1 == "Mumbai Indians"]
# Out:
#         id  season       city        date           team1  \
# 1        2    2017       Pune  2017-04-06  Mumbai Indians
# 23      24    2017     Mumbai  2017-04-22  Mumbai Indians
# 43      44    2017      Delhi  2017-05-06  Mumbai Indians
# 46      47    2017  Hyderabad  2017-05-08  Mumbai Indians
# 52      53    2017    Kolkata  2017-05-13  Mumbai Indians
# ..     ...     ...        ...         ...             ...
# 729  11325    2019      Delhi    18/04/19  Mumbai Indians
# 731  11327    2019     Jaipur    20/04/19  Mumbai Indians
# 739  11335    2019    Chennai    26/04/19  Mumbai Indians
# 746  11342    2019     Mumbai    02/05/19  Mumbai Indians
# 755  11415    2019  Hyderabad    12/05/19  Mumbai Indians
#
#                       team2             toss_winner toss_decision  result  \
# 1    Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 23         Delhi Daredevils        Delhi Daredevils         field  normal
# ...

# %%
import numpy as np

# %%
#Creating a dataset
mrg_file = pd.merge(
    file1, 
    file2, 
    left_on='match_id',
    right_on='id'
)
mrg_file.to_csv('match.csv')

# %%
mrg_file
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
mrg_file.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
mrg_file.info
# Out:
# <bound method DataFrame.info of         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
#Trying to get close to solution by merging two csv files
#filtering by mumbai indians 
mrg_file[mrg_file.batting_team == 'Mumbai Indians']
# Out:
#         match_id  inning    batting_team            bowling_team  over  ball  \
# 248            2       1  Mumbai Indians  Rising Pune Supergiant     1     1
# 249            2       1  Mumbai Indians  Rising Pune Supergiant     1     2
# 250            2       1  Mumbai Indians  Rising Pune Supergiant     1     3
# 251            2       1  Mumbai Indians  Rising Pune Supergiant     1     4
# 252            2       1  Mumbai Indians  Rising Pune Supergiant     1     5
# ...          ...     ...             ...                     ...   ...   ...
# 178949     11415       1  Mumbai Indians     Chennai Super Kings    20     2
# 178950     11415       1  Mumbai Indians     Chennai Super Kings    20     3
# 178951     11415       1  Mumbai Indians     Chennai Super Kings    20     4
# 178952     11415       1  Mumbai Indians     Chennai Super Kings    20     5
# 178953     11415       1  Mumbai Indians     Chennai Super Kings    20     6
#
# ...

# %%
#filtering by delhi daredevils as batting team
mrg_file[mrg_file.batting_team == 'Delhi Daredevils']
# Out:
#         match_id  inning      batting_team                 bowling_team  over  \
# 1084           5       2  Delhi Daredevils  Royal Challengers Bangalore     1
# 1085           5       2  Delhi Daredevils  Royal Challengers Bangalore     1
# 1086           5       2  Delhi Daredevils  Royal Challengers Bangalore     1
# 1087           5       2  Delhi Daredevils  Royal Challengers Bangalore     1
# 1088           5       2  Delhi Daredevils  Royal Challengers Bangalore     1
# ...          ...     ...               ...                          ...   ...
# 163396      7948       1  Delhi Daredevils               Mumbai Indians    20
# 163397      7948       1  Delhi Daredevils               Mumbai Indians    20
# 163398      7948       1  Delhi Daredevils               Mumbai Indians    20
# 163399      7948       1  Delhi Daredevils               Mumbai Indians    20
# 163400      7948       1  Delhi Daredevils               Mumbai Indians    20
#
# ...

# %%
#Filtering by delhi capitals as batting team
mrg_file[mrg_file.batting_team == 'Delhi Capitals']
# Out:
#         match_id  inning    batting_team         bowling_team  over  ball  \
# 165208     11139       1  Delhi Capitals       Mumbai Indians     1     1
# 165209     11139       1  Delhi Capitals       Mumbai Indians     1     2
# 165210     11139       1  Delhi Capitals       Mumbai Indians     1     3
# 165211     11139       1  Delhi Capitals       Mumbai Indians     1     4
# 165212     11139       1  Delhi Capitals       Mumbai Indians     1     5
# ...          ...     ...             ...                  ...   ...   ...
# 178709     11414       1  Delhi Capitals  Chennai Super Kings    20     2
# 178710     11414       1  Delhi Capitals  Chennai Super Kings    20     3
# 178711     11414       1  Delhi Capitals  Chennai Super Kings    20     4
# 178712     11414       1  Delhi Capitals  Chennai Super Kings    20     5
# 178713     11414       1  Delhi Capitals  Chennai Super Kings    20     6
#
#          batsman non_striker     bowler  is_super_over  ...  result  \
# ...

# %%
mrg_file.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %%
#Filtering by match winners as mumbai indians
file2[file2.winner == 'Mumbai Indians']
# Out:
#         id  season       city        date                        team1  \
# 6        7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11      12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 15      16    2017     Mumbai  2017-04-16                Gujarat Lions
# 21      22    2017     Indore  2017-04-20              Kings XI Punjab
# ..     ...     ...        ...         ...                          ...
# 739  11335    2019    Chennai    26/04/19               Mumbai Indians
# 746  11342    2019     Mumbai    02/05/19               Mumbai Indians
# 751  11347    2019     Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019    Chennai    07/05/19          Chennai Super Kings
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# ...

# %%
#Filtering by match winners as delhi capitals
file2[file2.winner == 'Delhi Capitals']
# Out:
#         id  season           city      date                        team1  \
# 698  11139    2019         Mumbai  24/03/19               Delhi Capitals
# 705  11146    2019          Delhi  30/03/19        Kolkata Knight Riders
# 715  11311    2019      Bengaluru  07/04/19  Royal Challengers Bangalore
# 721  11317    2019        Kolkata  12/04/19        Kolkata Knight Riders
# 725  11321    2019      Hyderabad  14/04/19               Delhi Capitals
# 732  11328    2019          Delhi  20/04/19              Kings XI Punjab
# 735  11331    2019         Jaipur  22/04/19             Rajasthan Royals
# 741  11337    2019          Delhi  28/04/19               Delhi Capitals
# 748  11344    2019          Delhi  04/05/19             Rajasthan Royals
# 753  11413    2019  Visakhapatnam  08/05/19          Sunrisers Hyderabad
#
#                            team2          toss_winner toss_decision  result  \
# 698               Mumbai Indians       Mumbai Indians         field  normal
# ...

# %%
#Filtering by match winners as delhi daredevils
file2[file2.winner == 'Delhi Daredevils']
# Out:
#        id  season    city        date                team1  \
# 8       9    2017    Pune  2017-04-11     Delhi Daredevils
# 14     15    2017   Delhi  2017-04-15     Delhi Daredevils
# 38     39    2017   Delhi  2017-05-02  Sunrisers Hyderabad
# 40     41    2017   Delhi  2017-05-04        Gujarat Lions
# 48     49    2017  Kanpur  2017-05-10        Gujarat Lions
# ..    ...     ...     ...         ...                  ...
# 644  7902    2018  Mumbai    14/04/18       Mumbai Indians
# 661  7919    2018   Delhi    27/04/18     Delhi Daredevils
# 667  7925    2018   Delhi    02/05/18     Delhi Daredevils
# 687  7945    2018   Delhi    18/05/18     Delhi Daredevils
# 690  7948    2018   Delhi    20/05/18     Delhi Daredevils
#
#                       team2             toss_winner toss_decision  result  \
# 8    Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 14          Kings XI Punjab        Delhi Daredevils           bat  normal
# ...

# %%
file2
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
#Creating a new dataset with mumbai and delhi vs other teams
filtr_data1 = file2[(file2.team1 == "Mumbai Indians") | 
                    (file2.team1 == 'Delhi Daredevils')  | 
                    (file2.team1 == 'Delhi Capitals')]

# %%
#Viewing dataset
filtr_data1
# Out:
#         id  season           city        date             team1  \
# 1        2    2017           Pune  2017-04-06    Mumbai Indians
# 8        9    2017           Pune  2017-04-11  Delhi Daredevils
# 14      15    2017          Delhi  2017-04-15  Delhi Daredevils
# 17      18    2017          Delhi  2017-04-17  Delhi Daredevils
# 23      24    2017         Mumbai  2017-04-22    Mumbai Indians
# ..     ...     ...            ...         ...               ...
# 739  11335    2019        Chennai    26/04/19    Mumbai Indians
# 741  11337    2019          Delhi    28/04/19    Delhi Capitals
# 746  11342    2019         Mumbai    02/05/19    Mumbai Indians
# 754  11414    2019  Visakhapatnam    10/05/19    Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19    Mumbai Indians
#
#                            team2             toss_winner toss_decision  \
# 1         Rising Pune Supergiant  Rising Pune Supergiant         field
# ...

# %%
filtr_data1.info
# Out:
# <bound method DataFrame.info of         id  season           city        date             team1  \
# 1        2    2017           Pune  2017-04-06    Mumbai Indians
# 8        9    2017           Pune  2017-04-11  Delhi Daredevils
# 14      15    2017          Delhi  2017-04-15  Delhi Daredevils
# 17      18    2017          Delhi  2017-04-17  Delhi Daredevils
# 23      24    2017         Mumbai  2017-04-22    Mumbai Indians
# ..     ...     ...            ...         ...               ...
# 739  11335    2019        Chennai    26/04/19    Mumbai Indians
# 741  11337    2019          Delhi    28/04/19    Delhi Capitals
# 746  11342    2019         Mumbai    02/05/19    Mumbai Indians
# 754  11414    2019  Visakhapatnam    10/05/19    Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19    Mumbai Indians
#
#                            team2             toss_winner toss_decision  \
# 1         Rising Pune Supergiant  Rising Pune Supergiant         field
# ...

# %%
filtr_data1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#Categorizing in dataset
filtr_data1.team1.astype('category')
# Out:
# 1        Mumbai Indians
# 8      Delhi Daredevils
# 14     Delhi Daredevils
# 17     Delhi Daredevils
# 23       Mumbai Indians
#              ...
# 739      Mumbai Indians
# 741      Delhi Capitals
# 746      Mumbai Indians
# 754      Delhi Capitals
# 755      Mumbai Indians
# Name: team1, Length: 179, dtype: category
# Categories (3, object): [Delhi Capitals, Delhi Daredevils, Mumbai Indians]

# %%
filtr_data1
# Out:
#         id  season           city        date             team1  \
# 1        2    2017           Pune  2017-04-06    Mumbai Indians
# 8        9    2017           Pune  2017-04-11  Delhi Daredevils
# 14      15    2017          Delhi  2017-04-15  Delhi Daredevils
# 17      18    2017          Delhi  2017-04-17  Delhi Daredevils
# 23      24    2017         Mumbai  2017-04-22    Mumbai Indians
# ..     ...     ...            ...         ...               ...
# 739  11335    2019        Chennai    26/04/19    Mumbai Indians
# 741  11337    2019          Delhi    28/04/19    Delhi Capitals
# 746  11342    2019         Mumbai    02/05/19    Mumbai Indians
# 754  11414    2019  Visakhapatnam    10/05/19    Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19    Mumbai Indians
#
#                            team2             toss_winner toss_decision  \
# 1         Rising Pune Supergiant  Rising Pune Supergiant         field
# ...

# %%
#Renaming delhi daredevils to delhi capitals
filtr_data1 = filtr_data1.replace(['Delhi Daredevils'], 'Delhi Capitals')

# %%
filtr_data1
# Out:
#         id  season           city        date           team1  \
# 1        2    2017           Pune  2017-04-06  Mumbai Indians
# 8        9    2017           Pune  2017-04-11  Delhi Capitals
# 14      15    2017          Delhi  2017-04-15  Delhi Capitals
# 17      18    2017          Delhi  2017-04-17  Delhi Capitals
# 23      24    2017         Mumbai  2017-04-22  Mumbai Indians
# ..     ...     ...            ...         ...             ...
# 739  11335    2019        Chennai    26/04/19  Mumbai Indians
# 741  11337    2019          Delhi    28/04/19  Delhi Capitals
# 746  11342    2019         Mumbai    02/05/19  Mumbai Indians
# 754  11414    2019  Visakhapatnam    10/05/19  Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19  Mumbai Indians
#
#                            team2             toss_winner toss_decision  \
# 1         Rising Pune Supergiant  Rising Pune Supergiant         field
# 8         Rising Pune Supergiant  Rising Pune Supergiant         field
# ...

# %%
#Filtering winner by mumbai indians
filtr_data1[filtr_data1.winner == 'Mumbai Indians']
# Out:
#         id  season            city        date           team1  \
# 23      24    2017          Mumbai  2017-04-22  Mumbai Indians
# 43      44    2017           Delhi  2017-05-06  Mumbai Indians
# 52      53    2017         Kolkata  2017-05-13  Mumbai Indians
# 58      59    2017       Hyderabad  2017-05-21  Mumbai Indians
# 81      82    2008          Mumbai  2008-05-04  Mumbai Indians
# 101    102    2008       Hyderabad  2008-05-18  Mumbai Indians
# 117    118    2009       Cape Town  2009-04-18  Mumbai Indians
# 131    132    2009  Port Elizabeth  2009-04-27  Mumbai Indians
# 137    138    2009     East London  2009-05-01  Mumbai Indians
# 152    153    2009  Port Elizabeth  2009-05-10  Mumbai Indians
# 175    176    2010          Mumbai  2010-03-13  Mumbai Indians
# 182    183    2010           Delhi  2010-03-17  Mumbai Indians
# 198    199    2010          Mumbai  2010-03-28  Mumbai Indians
# 206    207    2010          Mumbai  2010-04-03  Mumbai Indians
# ...

# %%
#Filtering winner by delhi capitals
filtr_data1[filtr_data1.winner == 'Delhi Capitals']
# Out:
#         id  season           city        date           team1  \
# 8        9    2017           Pune  2017-04-11  Delhi Capitals
# 14      15    2017          Delhi  2017-04-15  Delhi Capitals
# 50      51    2017          Delhi  2017-05-12  Delhi Capitals
# 75      76    2008          Delhi  2008-04-30  Delhi Capitals
# 97      98    2008          Delhi  2008-05-15  Delhi Capitals
# 108    109    2008          Delhi  2008-05-24  Mumbai Indians
# 124    125    2009         Durban  2009-04-23  Delhi Capitals
# 149    150    2009    East London  2009-05-08  Mumbai Indians
# 157    158    2009         Durban  2009-05-13  Delhi Capitals
# 164    165    2009   Bloemfontein  2009-05-17  Delhi Capitals
# 169    170    2009      Centurion  2009-05-21  Mumbai Indians
# 196    197    2010      Bangalore  2010-03-25  Delhi Capitals
# 199    200    2010          Delhi  2010-03-29  Delhi Capitals
# 202    203    2010          Delhi  2010-03-31  Delhi Capitals
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 20, 15

# %%
#Number of times mumbai indians won after winning toss
plot1 = plt.hist(filtr_data1[filtr_data1.winner == 'Mumbai Indians'].toss_winner, bins=20)

# %%
#Number of times delhi won after winning toss
plot2 = plt.hist(filtr_data1[filtr_data1.winner == 'Delhi Capitals'].toss_winner, bins=20)

# %%
#Number of times mumbai won wrt toss decision
plot3 = plt.hist(filtr_data1[filtr_data1.winner == 'Mumbai Indians'].toss_decision, bins=20)

# %%
#Number of times delhi won wrt toss decision
plot4 = plt.hist(filtr_data1[filtr_data1.winner == 'Delhi Capitals'].toss_decision, bins=20)

# %% [markdown]
# #Number of times MI won after winning toss - 25
# #MI won with fielding - 33
# #MI won with batting - 28
#
# #Number of times DC won after winning toss - 16
# #DC won with fielding - 20
# #DC won with batting - 15
#
# #Total number of times MI won - 25+33+28 = 86/100 = 0.86
# #Total number of times DC won - 16+20+15 = 51/100 = 0.51
#
# # 01. Histogram trends plotted show Mumbai Indians' chances of winning greater than Delhi Capitals.
# # 02. Similarly, toss winning captain is likely to choose fielding as higher wins are recorded that way.

# %%
file1[file1.batsman == 'R Sharma']
# Out:
#         match_id  inning     batting_team                 bowling_team  over  \
# 45930        195       1  Deccan Chargers             Rajasthan Royals    19
# 45931        195       1  Deccan Chargers             Rajasthan Royals    19
# 45932        195       1  Deccan Chargers             Rajasthan Royals    19
# 45933        195       1  Deccan Chargers             Rajasthan Royals    19
# 45934        195       1  Deccan Chargers             Rajasthan Royals    19
# ...          ...     ...              ...                          ...   ...
# 93597        395       2    Pune Warriors               Mumbai Indians    20
# 93598        395       2    Pune Warriors               Mumbai Indians    20
# 95322        402       2    Pune Warriors          Sunrisers Hyderabad    19
# 100161       422       2    Pune Warriors          Chennai Super Kings    20
# 101119       426       2    Pune Warriors  Royal Challengers Bangalore    20
#
# ...

# %%
file1.batsman.astype('category')
# Out:
# 0         DA Warner
# 1         DA Warner
# 2         DA Warner
# 3         DA Warner
# 4         DA Warner
#             ...
# 179073    RA Jadeja
# 179074    SR Watson
# 179075    SR Watson
# 179076    SN Thakur
# 179077    SN Thakur
# Name: batsman, Length: 179078, dtype: category
# Categories (516, object): [A Ashish Reddy, A Chandila, A Chopra, A Choudhary, ..., Yashpal Singh, Younis Khan, Yuvraj Singh, Z Khan]

# %%
file1.batsman = file1.batsman.astype('category')

# %%
file1.batsman.cat.categories
# Out:
# Index(['A Ashish Reddy', 'A Chandila', 'A Chopra', 'A Choudhary',
#        'A Dananjaya', 'A Flintoff', 'A Hales', 'A Joseph', 'A Kumble',
#        'A Mishra',
#        ...
#        'Y Nagar', 'Y Venugopal Rao', 'YA Abdulla', 'YK Pathan', 'YS Chahal',
#        'YV Takawale', 'Yashpal Singh', 'Younis Khan', 'Yuvraj Singh',
#        'Z Khan'],
#       dtype='object', length=516)

# %%
#Plotting to show runs made by Rohit sharma in seasons
plot5 = plt.hist(file1[file1.batsman == 'R Sharma'].batsman_runs, bins = 20)

# %%
#Rabada against teams played
plot6 = plt.hist(file1[file1.bowler == 'K Rabada'].batting_team, bins = 20)

# %%
rabada1 = file1[(file1.bowler == 'K Rabada') & (file1.dismissal_kind == 'bowled')] #6 records

# %%
rabada2 = file1[(file1.bowler == 'K Rabada') & (file1.dismissal_kind == 'caught')] #25 records

# %%
file1.wide_runs
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         2
#          ..
# 179073    0
# 179074    0
# 179075    0
# 179076    0
# 179077    0
# Name: wide_runs, Length: 179078, dtype: int64

# %%
#Plotting all wides in MI vs DC
plot7 = plt.hist(file1[(file1.batting_team == 'Mumbai Indians') & (file1.bowling_team == 'Delhi Capitals')].wide_runs, bins = 20)
plot8 = plt.hist(file1[(file1.batting_team == 'Delhi Capitals') & (file1.bowling_team == 'Mumbai Indians')].wide_runs, bins = 20)

# %% [markdown]
# # Could not accurately predict the count for rabada's wickets and total number of wides that will be bowled due to inadequate practice.
