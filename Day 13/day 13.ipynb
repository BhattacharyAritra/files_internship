# %%
import pandas as pd

# %%
delivery=pd.read_csv("E:\\2020 WPL WIDHYA\\Day 13\\deliveries.csv")
match=pd.read_csv("E:\\2020 WPL WIDHYA\\Day 13\\matches.csv")

# %%
fl_deli=delivery[((delivery.batting_team=='Chennai Super Kings')&(delivery.bowling_team=='Mumbai Indians'))
                |
                ((delivery.batting_team=='Mumbai Indians')&(delivery.bowling_team=='Chennai Super Kings'))]
fl_deli
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 15486         67       1  Chennai Super Kings  Mumbai Indians     1     1
# 15487         67       1  Chennai Super Kings  Mumbai Indians     1     2
# 15488         67       1  Chennai Super Kings  Mumbai Indians     1     3
# 15489         67       1  Chennai Super Kings  Mumbai Indians     1     4
# 15490         67       1  Chennai Super Kings  Mumbai Indians     1     5
# ...          ...     ...                  ...             ...   ...   ...
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# ...

# %%
fl_deli.shape
# Out:
# (6812, 21)

# %%
fl_deli.describe()
# Out:
#            match_id       inning         over         ball  is_super_over  \
# count   6812.000000  6812.000000  6812.000000  6812.000000         6812.0
# mean    2466.662361     1.489724    10.283324     3.636671            0.0
# std     4107.186261     0.499931     5.691104     1.822137            0.0
# min       67.000000     1.000000     1.000000     1.000000            0.0
# 25%      234.000000     1.000000     5.000000     2.000000            0.0
# 50%      454.000000     1.000000    10.000000     4.000000            0.0
# 75%      576.000000     2.000000    15.000000     5.000000            0.0
# max    11415.000000     2.000000    20.000000     9.000000            0.0
#
#          wide_runs     bye_runs  legbye_runs  noball_runs  penalty_runs  \
# count  6812.000000  6812.000000  6812.000000  6812.000000        6812.0
# mean      0.041985     0.003376     0.020552     0.004404           0.0
# std       0.267671     0.094576     0.195051     0.066221           0.0
# ...

# %%
fl_deli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6812 entries, 15486 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          6812 non-null   int64
#  1   inning            6812 non-null   int64
#  2   batting_team      6812 non-null   object
#  3   bowling_team      6812 non-null   object
#  4   over              6812 non-null   int64
#  5   ball              6812 non-null   int64
#  6   batsman           6812 non-null   object
#  7   non_striker       6812 non-null   object
#  8   bowler            6812 non-null   object
#  9   is_super_over     6812 non-null   int64
#  10  wide_runs         6812 non-null   int64
#  11  bye_runs          6812 non-null   int64
#  12  legbye_runs       6812 non-null   int64
#  13  noball_runs       6812 non-null   int64
#  14  penalty_runs      6812 non-null   int64
#  15  batsman_runs      6812 non-null   int64
# ...

# %%
fl_mat=match[((match.team1=='Chennai Super Kings')&(match.team2=='Mumbai Indians'))
            |
            ((match.team1=='Mumbai Indians')&(match.team2=='Chennai Super Kings'))]
fl_mat
# Out:
#         id  season            city        date                team1  \
# 66      67    2008         Chennai  2008-04-23  Chennai Super Kings
# 95      96    2008          Mumbai  2008-05-14  Chennai Super Kings
# 117    118    2009       Cape Town  2009-04-18       Mumbai Indians
# 161    162    2009  Port Elizabeth  2009-05-16       Mumbai Indians
# 193    194    2010          Mumbai  2010-03-25  Chennai Super Kings
# 210    211    2010         Chennai  2010-04-06  Chennai Super Kings
# 233    234    2010          Mumbai  2010-04-25  Chennai Super Kings
# 256    257    2011          Mumbai  2011-04-22       Mumbai Indians
# 307    308    2012         Chennai  2012-04-04  Chennai Super Kings
# 354    355    2012          Mumbai  2012-05-06  Chennai Super Kings
# 378    379    2012       Bangalore  2012-05-23  Chennai Super Kings
# 385    386    2013         Chennai  2013-04-06       Mumbai Indians
# 429    430    2013          Mumbai  2013-05-05       Mumbai Indians
# ...

# %%
fl_deli.match_id.unique()
# Out:
# array([   67,    96,   118,   162,   194,   211,   234,   257,   308,
#          355,   379,   386,   430,   454,   457,   470,   490,   515,
#          530,   559,   573,   576,  7894,  7920, 11151, 11335, 11412,
#        11415], dtype=int64)

# %%
fl_mat.id.unique()
# Out:
# array([   67,    96,   118,   162,   194,   211,   234,   257,   308,
#          355,   379,   386,   430,   454,   457,   470,   490,   515,
#          530,   559,   573,   576,  7894,  7920, 11151, 11335, 11412,
#        11415], dtype=int64)

# %%
mat_deli=pd.merge(fl_mat, fl_deli, left_on='id',right_on='match_id')
mat_deli.to_csv('matchinfo.csv')

# %%
play_info=pd.read_csv("E:\\2020 WPL WIDHYA\\Day 13\\matchinfo.csv")
play_info.describe()
# Out:
#         Unnamed: 0            id       season  dl_applied  win_by_runs  \
# count  6812.000000   6812.000000  6812.000000      6812.0  6812.000000
# mean   3405.500000   2466.662361  2013.458162         0.0    14.452143
# std    1966.599349   4107.186261     3.399566         0.0    18.028882
# min       0.000000     67.000000  2008.000000         0.0     0.000000
# 25%    1702.750000    234.000000  2010.000000         0.0     0.000000
# 50%    3405.500000    454.000000  2013.000000         0.0     6.000000
# 75%    5108.250000    576.000000  2015.000000         0.0    24.000000
# max    6811.000000  11415.000000  2019.000000         0.0    60.000000
#
#        win_by_wickets      match_id       inning         over         ball  \
# count     6812.000000   6812.000000  6812.000000  6812.000000  6812.000000
# mean         2.652085   2466.662361     1.489724    10.283324     3.636671
# std          3.266408   4107.186261     0.499931     5.691104     1.822137
# ...

# %%
play_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6812 entries, 0 to 6811
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        6812 non-null   int64
#  1   id                6812 non-null   int64
#  2   season            6812 non-null   int64
#  3   city              6575 non-null   object
#  4   date              6812 non-null   object
#  5   team1             6812 non-null   object
#  6   team2             6812 non-null   object
#  7   toss_winner       6812 non-null   object
#  8   toss_decision     6812 non-null   object
#  9   result            6812 non-null   object
#  10  dl_applied        6812 non-null   int64
#  11  winner            6812 non-null   object
#  12  win_by_runs       6812 non-null   int64
#  13  win_by_wickets    6812 non-null   int64
#  14  player_of_match   6812 non-null   object
#  15  venue             6812 non-null   object
# ...

# %%
play_info.batting_team.unique()
# Out:
# array(['Chennai Super Kings', 'Mumbai Indians'], dtype=object)

# %%
play_info.winner.unique()
# Out:
# array(['Chennai Super Kings', 'Mumbai Indians'], dtype=object)

# %%
play_info[play_info.bowler=='TA Boult']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3, match_id, inning, batting_team, bowling_team, over, ball, batsman, non_striker, bowler, is_super_over, wide_runs, bye_runs, legbye_runs, noball_runs, penalty_runs, batsman_runs, extra_runs, total_runs, player_dismissed, dismissal_kind, fielder]
# Index: []
#
# [0 rows x 40 columns]

# %%
#Overs having 6 and 4 runs scored together
runs_a=play_info[(play_info.total_runs==6)|(play_info.total_runs==4)].over.unique()
runs_a
# Out:
# array([ 1,  2,  3,  5,  6,  9, 10, 11, 12, 13, 14, 16, 17, 18, 19, 20,  4,
#         8,  7, 15], dtype=int64)

# %%
#Overs having 6 and 4 runs scored together value
runs_b=play_info[(play_info.total_runs==6)|(play_info.total_runs==4)].over.value_counts()
runs_b
# Out:
# 6     84
# 5     82
# 4     75
# 19    68
# 20    64
# 18    64
# 17    63
# 16    60
# 2     59
# 14    58
# 3     52
# 11    52
# 15    51
# 10    44
# 9     41
# 12    40
# 13    38
# 7     35
# 1     33
# 8     29
# Name: over, dtype: int64

# %%
import numpy as np

# %%
np.mean(runs_a)
# Out:
# 10.5

# %%
game_info=play_info[(play_info.season==2019)|(play_info.season==2018)|(play_info.season==2017)|(play_info.season==2016)]
game_info
# Out:
#       Unnamed: 0     id  season       city      date           team1  \
# 5347        5347   7894    2018     Mumbai  07/04/18  Mumbai Indians
# 5348        5348   7894    2018     Mumbai  07/04/18  Mumbai Indians
# 5349        5349   7894    2018     Mumbai  07/04/18  Mumbai Indians
# 5350        5350   7894    2018     Mumbai  07/04/18  Mumbai Indians
# 5351        5351   7894    2018     Mumbai  07/04/18  Mumbai Indians
# ...          ...    ...     ...        ...       ...             ...
# 6807        6807  11415    2019  Hyderabad  12/05/19  Mumbai Indians
# 6808        6808  11415    2019  Hyderabad  12/05/19  Mumbai Indians
# 6809        6809  11415    2019  Hyderabad  12/05/19  Mumbai Indians
# 6810        6810  11415    2019  Hyderabad  12/05/19  Mumbai Indians
# 6811        6811  11415    2019  Hyderabad  12/05/19  Mumbai Indians
#
#                     team2          toss_winner toss_decision  result  ...  \
# ...

# %%
#6 and 4 runs after filtering
runs_a=game_info[(game_info.total_runs==6)|(game_info.total_runs==4)].over.unique()
runs_a
# Out:
# array([ 1,  4,  5,  6,  8,  9, 11, 12, 14, 15, 17, 19,  2, 13, 16, 18, 20,
#         3,  7, 10], dtype=int64)

# %%
#6 and 4 runs value counting after filtering
runs_b=game_info[(game_info.total_runs==6)|(game_info.total_runs==4)].over.value_counts()
runs_b
# Out:
# 19    19
# 5     18
# 4     17
# 16    16
# 18    14
# 11    14
# 20    13
# 6     13
# 3     12
# 14    11
# 1     10
# 15    10
# 17     9
# 2      9
# 12     8
# 9      7
# 7      6
# 10     6
# 8      5
# 13     3
# Name: over, dtype: int64

# %%
np.average(runs_b)
# Out:
# 11.0

# %%
np.mean(runs_a)
# Out:
# 10.5

# %%
np.mean(runs_a)
# Out:
# 10.5

# %%
np.var(runs_a)
# Out:
# 33.25

# %%
np.std(runs_a)
# Out:
# 5.766281297335398

# %%
import itertools as it

# %%
it.combinations(game_info[(game_info.total_runs==6)|(game_info.total_runs==4)].dropna(),2)

# %%
it.combinations(runs_a,2)

# %%
it.permutations(runs_a,2)

# %%
#Bowler lethality score=
#((no.of wickets+no.of dot balls bowled)-(no.of boundaries scored/no.of boundaries scored off the bowler))/total no.of balls bowled by the bowler in the match

# %%
dot_balls=game_info[(game_info.batsman_runs==0)&(game_info.total_runs==0)].ball
dot_balls.count()
# Out:
# 573

# %%
game_info[game_info['batsman'].str.contains('kock',case=False)]
# Out:
#       Unnamed: 0     id  season       city      date                team1  \
# 5840        5840  11151    2019     Mumbai  03/04/19       Mumbai Indians
# 5841        5841  11151    2019     Mumbai  03/04/19       Mumbai Indians
# 5842        5842  11151    2019     Mumbai  03/04/19       Mumbai Indians
# 5843        5843  11151    2019     Mumbai  03/04/19       Mumbai Indians
# 5844        5844  11151    2019     Mumbai  03/04/19       Mumbai Indians
# 5853        5853  11151    2019     Mumbai  03/04/19       Mumbai Indians
# 5854        5854  11151    2019     Mumbai  03/04/19       Mumbai Indians
# 6094        6094  11335    2019    Chennai  26/04/19       Mumbai Indians
# 6095        6095  11335    2019    Chennai  26/04/19       Mumbai Indians
# 6099        6099  11335    2019    Chennai  26/04/19       Mumbai Indians
# 6100        6100  11335    2019    Chennai  26/04/19       Mumbai Indians
# 6102        6102  11335    2019    Chennai  26/04/19       Mumbai Indians
# ...

# %%
game_info[(game_info.batsman=='Q de Kock')&(game_info.batsman_runs==4)].ball
# Out:
# 5853    2
# 6105    2
# 6461    5
# 6467    4
# Name: ball, dtype: int64

# %%
dotballs=game_info[(game_info.bye_runs==0)|(game_info.legbye_runs==0)|(game_info.wide_runs==0)|(game_info.noball_runs==0)|(game_info.penalty_runs==0)].bowler.count

# %%
dotballs
# Out:
# <bound method Series.count of 5347     DL Chahar
# 5348     DL Chahar
# 5349     DL Chahar
# 5350     DL Chahar
# 5351     DL Chahar
#            ...
# 6807    SL Malinga
# 6808    SL Malinga
# 6809    SL Malinga
# 6810    SL Malinga
# 6811    SL Malinga
# Name: bowler, Length: 1465, dtype: object>

# %%
totalballs=game_info.ball.dropna()

# %%
totalballs
# Out:
# 5347    1
# 5348    2
# 5349    3
# 5350    4
# 5351    5
#        ..
# 6807    2
# 6808    3
# 6809    4
# 6810    5
# 6811    6
# Name: ball, Length: 1465, dtype: int64

# %%
ratio=dotballs/totalballs
ratio.unique()
# Out:
# array([1.])

# %%
delivery[delivery.bowler=='TA Boult']
# Out:
#         match_id  inning         batting_team           bowling_team  over  \
# 495            3       1        Gujarat Lions  Kolkata Knight Riders     1
# 496            3       1        Gujarat Lions  Kolkata Knight Riders     1
# 497            3       1        Gujarat Lions  Kolkata Knight Riders     1
# 498            3       1        Gujarat Lions  Kolkata Knight Riders     1
# 499            3       1        Gujarat Lions  Kolkata Knight Riders     1
# ...          ...     ...                  ...                    ...   ...
# 178813     11414       2  Chennai Super Kings         Delhi Capitals    17
# 178814     11414       2  Chennai Super Kings         Delhi Capitals    17
# 178815     11414       2  Chennai Super Kings         Delhi Capitals    17
# 178816     11414       2  Chennai Super Kings         Delhi Capitals    17
# 178817     11414       2  Chennai Super Kings         Delhi Capitals    17
#
# ...

# %%
game_info[game_info.winner=='Mumbai Indians'].toss_decision.value_counts()
# Out:
# field    734
# bat      485
# Name: toss_decision, dtype: int64

# %%
game_info[game_info.winner=='Chennai Super Kings'].toss_decision.value_counts()
# Out:
# field    246
# Name: toss_decision, dtype: int64

# %%
game_info[game_info.winner=='Mumbai Indians'].toss_winner.value_counts()
# Out:
# Chennai Super Kings    724
# Mumbai Indians         495
# Name: toss_winner, dtype: int64

# %%
game_info[game_info.winner=='Chennai Super Kings'].toss_winner.value_counts()
# Out:
# Chennai Super Kings    246
# Name: toss_winner, dtype: int64
