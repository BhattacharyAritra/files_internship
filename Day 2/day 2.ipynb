# %%
import pandas as pd

# %%
dlvr = pd.read_csv('E:\\2020 WPL WIDHYA\\Day 2\\deliveries.csv')
mch = pd.read_csv('E:\\2020 WPL WIDHYA\\Day 2\\matches.csv')

# %%
dlvr.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
mch.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
type(mch)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
mch[mch.winner == 'Kolkata Knight Riders'].toss_decision
# Out:
# 2      field
# 10     field
# 13     field
# 17       bat
# 26     field
#        ...
# 701    field
# 712    field
# 716    field
# 742    field
# 747    field
# Name: toss_decision, Length: 92, dtype: object

# %%
mch[mch.winner == 'Royal Challengers Bangalore'].toss_decision
# Out:
# 4        bat
# 19     field
# 54       bat
# 62       bat
# 79       bat
#        ...
# 723    field
# 730    field
# 734    field
# 737    field
# 749    field
# Name: toss_decision, Length: 84, dtype: object

# %%
fil_mch = mch[((mch.team1 == 'Kolkata Knight Riders') & (mch.team2 == 'Royal Challengers Bangalore'))
             | ((mch.team2 == 'Kolkata Knight Riders') & (mch.team1 == 'Royal Challengers Bangalore'))
             ]

# %%
fil_mch.count()
# Out:
# id                 24
# season             24
# city               24
# date               24
# team1              24
# team2              24
# toss_winner        24
# toss_decision      24
# result             24
# dl_applied         24
# winner             24
# win_by_runs        24
# win_by_wickets     24
# player_of_match    24
# venue              24
# umpire1            24
# umpire2            24
# umpire3             4
# dtype: int64

# %%
import seaborn as sb
import matplotlib.pyplot as mtp
# %matplotlib inline
mtp.rcParams['figure.figsize'] = 10, 6

# %% [markdown]
# KKR vs RCB

# %%
#RCB won by winning toss
plot = mtp.hist(fil_mch[fil_mch.winner == 'Royal Challengers Bangalore'].toss_winner, bins = 10)

# %%
#KKR won by winning toss
plot1 = mtp.hist(fil_mch[fil_mch.winner == 'Kolkata Knight Riders'].toss_winner, bins = 10)

# %%
#RCB won wrt toss decision
plot2 = mtp.hist(fil_mch[fil_mch.winner == 'Royal Challengers Bangalore'].toss_decision, bins = 10)

# %%
#KKR won wrt toss decision
plot3 = mtp.hist(fil_mch[fil_mch.winner == 'Kolkata Knight Riders'].toss_decision, bins =10)

# %% [markdown]
# Royal Challengers Bangalore:
#     won by winning toss = 8,
#     won by losing toss = 5,
#     won by batting = 1,
#     won by fielding = 9,
#     total = 23/100 = 0.23
#
# Kolkata Knight Riders:
#     won by winning toss = 9,
#     won by losing toss = 2,
#     won by batting = 2,
#     won by fielding = 12,
#     total = 25/100 = 0.25
#
# 01. Histogram trends show KKR's chances of winning greater than RCB.
# 02. Under normal circumstances, toss winning captain will decide to field.

# %%
dlvr.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
fil_dlvr = dlvr[((dlvr.batting_team == 'Kolkata Knight Riders') & (dlvr.bowling_team == 'Royal Challengers Bangalore'))
               |
               ((dlvr.batting_team == 'Royal Challengers Bangalore') & (dlvr.bowling_team == 'Kolkata Knight Riders'))]

# %%
fil_dlvr
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 6254          27       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6255          27       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6256          27       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6257          27       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6258          27       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 173253     11326       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 173254     11326       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 173255     11326       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 173256     11326       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 173257     11326       2  Kolkata Knight Riders  Royal Challengers Bangalore
#
# ...

# %%
#Plotting runs made by KD Karthik
plot4 = mtp.hist(fil_dlvr[fil_dlvr.batsman == 'KD Karthik'].batsman_runs, bins = 15)

# %%
run_karthik = np.var(fil_dlvr[fil_dlvr.batsman == 'KD Karthik'].batsman_runs)
print(run_karthik) #2.1363313609467465 ~ 2.14
# Out:
# 2.1363313609467465

# %%
#Plotting runs made by no balls
plot5 = mtp.hist(fil_dlvr[fil_dlvr.bowling_team == 'Kolkata Knight Riders'].noball_runs)

# %%
#Average no balls possible
noball = np.var(fil_dlvr.noball_runs)
print(noball) #0.004162823181445455 ~ 0.004
# Out:
# 0.004162823181445455

# %%
#Runs made by virat kohli
plot6 = mtp.hist(fil_dlvr[fil_dlvr.batsman == 'V Kohli'].batsman_runs, bins = 15)

# %%
#Virat 4s'
virat_4s = np.var(fil_dlvr[fil_dlvr.batsman == 'V Kohli'].total_runs)
print(virat_4s) #2.4230747478555883 ~ 2.42
# Out:
# 2.4230747478555883

# %% [markdown]
# As per calcualtions made,
# 03. Taking variations of the runs made by dinesh karthik in previous seasons, his score is predicted to be between 0-10. (2.14)
# 04. No balls variation is predicted to be 0. (0.004)
# 05. Virat Kohli is predicted to score around 0-2 boundaries. (2.42)
