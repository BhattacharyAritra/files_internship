# %%
import pandas as pd

# %%
dlv = pd.read_csv("E:\\2020 WPL WIDHYA\\Day 3\\deliveries.csv")
mtch = pd.read_csv("E:\\2020 WPL WIDHYA\\Day 3\\matches.csv")

# %%
mtch.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
srh = mtch[mtch.winner == 'Sunrisers Hyderabad']

# %%
srh.count()
# Out:
# id                 58
# season             58
# city               56
# date               58
# team1              58
# team2              58
# toss_winner        58
# toss_decision      58
# result             58
# dl_applied         58
# winner             58
# win_by_runs        58
# win_by_wickets     58
# player_of_match    58
# venue              58
# umpire1            58
# umpire2            58
# umpire3            16
# dtype: int64

# %%
mtch.count()
# Out:
# id                 756
# season             756
# city               749
# date               756
# team1              756
# team2              756
# toss_winner        756
# toss_decision      756
# result             756
# dl_applied         756
# winner             752
# win_by_runs        756
# win_by_wickets     756
# player_of_match    752
# venue              756
# umpire1            754
# umpire2            754
# umpire3            119
# dtype: int64

# %%
mtch.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
mtch_filt = mtch[(mtch.winner == 'Sunrisers Hyderabad') | (mtch.winner == 'Chennai Super Kings')]
mtch_filt
# Out:
#         id  season           city        date                  team1  \
# 0        1    2017      Hyderabad  2017-04-05    Sunrisers Hyderabad
# 5        6    2017      Hyderabad  2017-04-09          Gujarat Lions
# 18      19    2017      Hyderabad  2017-04-17    Sunrisers Hyderabad
# 20      21    2017      Hyderabad  2017-04-19    Sunrisers Hyderabad
# 31      32    2017     Chandigarh  2017-04-28    Sunrisers Hyderabad
# ..     ...     ...            ...         ...                    ...
# 733  11329    2019      Hyderabad    21/04/19  Kolkata Knight Riders
# 736  11332    2019        Chennai    23/04/19    Sunrisers Hyderabad
# 743  11339    2019      Hyderabad    29/04/19    Sunrisers Hyderabad
# 745  11341    2019        Chennai    01/05/19    Chennai Super Kings
# 754  11414    2019  Visakhapatnam    10/05/19         Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
mtch_filt.nunique()
# Out:
# id                 158
# season              12
# city                25
# date               153
# team1               12
# team2               13
# toss_winner         11
# toss_decision        2
# result               2
# dl_applied           2
# winner               2
# win_by_runs         50
# win_by_wickets      11
# player_of_match     58
# venue               33
# umpire1             45
# umpire2             50
# umpire3             21
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 20, 15

# %%
#matches won by srh winning toss in previous seasons
x = mtch_filt[mtch_filt.winner == 'Sunrisers Hyderabad'].toss_winner
plot1 = plt.hist(x, 25, alpha = 0.75)
plt.title('Matches won by SRH by winning toss vs Other teams')
plt.grid(True)

# %%
#matches won by csk winning toss in previous seasons
x1 = mtch_filt[mtch_filt.winner == 'Chennai Super Kings'].toss_winner
plot1 = plt.hist(x1, 25, alpha = 0.75)
plt.title('Matches won by CSK by winning toss vs Other teams')
plt.grid(True)

# %%
#matches won by srh by toss decision in previous seasons
x2 = mtch_filt[mtch_filt.winner == 'Sunrisers Hyderabad'].toss_decision
plot1 = plt.hist(x2, 25, alpha = 0.75)
plt.title('Matches won by SRH by toss decision vs Other teams')
plt.grid(True)

# %%
#matches won by csk by toss decision in previous seasons
x3 = mtch_filt[mtch_filt.winner == 'Chennai Super Kings'].toss_decision
plot1 = plt.hist(x3, 25, alpha = 0.75)
plt.title('Matches won by CSK by toss decision vs Other teams')
plt.grid(True)

# %% [markdown]
# SRH won
# by toss - 24
# by fielding - 33
# by batting - 21
# total = 24+33+21 = 78
#
# CSK won
# by toss - 57
# by fielding - 52
# by battiing - 48
# total = 57+52+48 = 157
#
# 01. Histogram trend calculation show the win of chennai super kings according to dataset of indian grounds. But due to the venue being offshore, results may differ.

# %%
dlv_filt = dlv[((dlv.bowling_team == 'Chennai Super Kings') & (dlv.batting_team == 'Sunrisers Hyderabad')) |
              ((dlv.bowling_team == 'Sunrisers Hyderabad') & (dlv.batting_team == 'Chennai Super Kings'))]
dlv_filt
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 97960        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# 97961        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# 97962        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# 97963        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# 97964        414       1  Sunrisers Hyderabad  Chennai Super Kings     1
# ...          ...     ...                  ...                  ...   ...
# 174689     11332       2  Chennai Super Kings  Sunrisers Hyderabad    20
# 174690     11332       2  Chennai Super Kings  Sunrisers Hyderabad    20
# 174691     11332       2  Chennai Super Kings  Sunrisers Hyderabad    20
# 174692     11332       2  Chennai Super Kings  Sunrisers Hyderabad    20
# 174693     11332       2  Chennai Super Kings  Sunrisers Hyderabad    20
#
#         ball    batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# ...

# %%
dlv_filt.head(15)
# Out:
#        match_id  inning         batting_team         bowling_team  over  ball  \
# 97960       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     1
# 97961       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     2
# 97962       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     3
# 97963       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     4
# 97964       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     5
# 97965       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     6
# 97966       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     1
# 97967       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     2
# 97968       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     3
# 97969       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     4
# 97970       414       1  Sunrisers Hyderabad  Chennai Super Kings     2     5
# ...

# %%
#Wides given by CSK
y = dlv_filt[dlv_filt.bowling_team == 'Chennai Super Kings'].wide_runs
plot2 = plt.hist(y, 25, alpha=0.75)
plt.title('Wide runs by CSK')
plt.grid(True)

# %%
#Wides given by SRH
y1 = dlv_filt[dlv_filt.bowling_team == 'Sunrisers Hyderabad'].wide_runs
plot2 = plt.hist(y1, 25, alpha=0.75)
plt.title('Wide runs by SRH')
plt.grid(True)

# %%
import numpy as np
# Out:
# 0.02949376230357834

# %%
#Number of wides
wides = np.mean(dlv_filt.wide_runs)
wides #0.029692832764505118
wides = np.var(dlv_filt.wide_runs)
wides #0.02949376230357834
# Out:
# 0.029692832764505118

# %%
#David Warner runs
runs = dlv_filt[dlv_filt.batsman == 'DA Warner'].total_runs
print(runs.count())

runs_mean = np.mean(runs)
print(runs_mean)
# Out:
# 192
# 1.703125

# %%
dlv_filt.nunique()
# Out:
# match_id            12
# inning               2
# batting_team         2
# bowling_team         2
# over                20
# ball                 9
# batsman             56
# non_striker         55
# bowler              46
# is_super_over        1
# wide_runs            3
# bye_runs             4
# legbye_runs          5
# noball_runs          2
# penalty_runs         1
# batsman_runs         7
# extra_runs           5
# total_runs           9
# player_dismissed    48
# dismissal_kind       6
# fielder             45
# dtype: int64

# %%
#Total run score
totrun_csk = dlv_filt[dlv_filt.batting_team == 'Chennai Super Kings'].total_runs
totrun_srh = dlv_filt[dlv_filt.batting_team == 'Sunrisers Hyderabad'].total_runs

print(np.mean(totrun_csk))
print(np.mean(totrun_srh))
# Out:
# 1.4532967032967032
# 1.3704206241519674
