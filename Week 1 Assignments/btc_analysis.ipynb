# %% [markdown]
# MICROTASK 1

# %%
# pip3 install pandas

# %% [markdown]
# MICROTASK 2

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("C:\\Users\\ari_b\\Documents\\Winternship by Widhya\\Week 1 Assignments\\btc_dataset.csv")

# %%
dataset.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
## 1024th value of btc_market_price column
dataset.btc_market_price[1023]
# Out:
# 13.6888

# %% [markdown]
# MICROTASK 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 15, 10

# %%
import scipy.stats as stats
from warnings import filterwarnings
filterwarnings('ignore')
sns.set(style = 'darkgrid', color_codes =  True)

# %%
dataset.columns
# Out:
# Index(['Date', 'btc_market_price', 'btc_total_bitcoins', 'btc_market_cap',
#        'btc_trade_volume', 'btc_blocks_size', 'btc_avg_block_size',
#        'btc_n_orphaned_blocks', 'btc_n_transactions_per_block',
#        'btc_median_confirmation_time', 'btc_hash_rate', 'btc_difficulty',
#        'btc_miners_revenue', 'btc_transaction_fees',
#        'btc_cost_per_transaction_percent', 'btc_cost_per_transaction',
#        'btc_n_unique_addresses', 'btc_n_transactions',
#        'btc_n_transactions_total', 'btc_n_transactions_excluding_popular',
#        'btc_n_transactions_excluding_chains_longer_than_100',
#        'btc_output_volume', 'btc_estimated_transaction_volume',
#        'btc_estimated_transaction_volume_usd'],
#       dtype='object')

# %%
## Individual jointplots plotting each column against another
sns.jointplot('btc_market_price', 'btc_total_bitcoins', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_market_cap', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_trade_volume', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_blocks_size', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_avg_block_size', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_n_orphaned_blocks', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_n_transactions_per_block', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_median_confirmation_time', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_hash_rate', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_difficulty', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_total_bitcoins', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_miners_revenue', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_transaction_fees', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_cost_per_transaction_percent', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_cost_per_transaction', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_n_unique_addresses', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_n_transactions', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_n_transactions_total', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_n_transactions_excluding_popular', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_n_transactions_excluding_chains_longer_than_100', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_output_volume', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_estimated_transaction_volume', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
sns.jointplot('btc_market_price', 'btc_estimated_transaction_volume_usd', data = dataset, kind = 'reg', height = 7).annotate(stats.pearsonr)
## btc_market_price VS btc_market_cap have pearson's r value equals to 1.

# %%
## Correlation Coefficient heatmap for summarization
k = 15
columns = dataset.corr().nlargest(k, 'btc_market_price')['btc_market_price'].index
perfect_correlation_plot = sns.heatmap(dataset[columns].corr(), annot=True, cmap = 'viridis')

# %% [markdown]
# MICROTASK 4

# %%
dataset.isnull().values.any()
# Out:
# True

# %%
dataset.btc_market_cap.isnull().values.any()
# Out:
# False

# %%
dataset.btc_n_transactions.isnull().values.any()
# Out:
# False

# %%
dataset.btc_miners_revenue.isnull().values.any()
# Out:
# False

# %%
dataset.btc_cost_per_transaction.isnull().values.any()
# Out:
# False

# %%
dataset.btc_difficulty.isnull().values.any()
# Out:
# True

# %%
dataset.btc_difficulty.dtype
# Out:
# dtype('float64')

# %%
dataset.btc_hash_rate.isnull().values.any()
# Out:
# False

# %%
dataset.btc_cost_per_transaction_percent.isnull().values.any()
# Out:
# False

# %%
dataset['btc_difficulty'].fillna(dataset.btc_difficulty.median(),inplace = True)

# %%
dataset.btc_difficulty.isnull().values.any()
# Out:
# False

# %% [markdown]
# MICROTASK 5

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
## creating a new subset from the previously existing dataset
subset_dataset = dataset.loc[:, 
[
    'btc_market_cap', 
    'btc_n_transactions', 
    'btc_miners_revenue', 
    'btc_cost_per_transaction', 
    'btc_difficulty', 
    'btc_hash_rate', 
    'btc_cost_per_transaction_percent',
    'btc_market_price' 
]]
subset_dataset.head(10)
# Out:
#    btc_market_cap  btc_n_transactions  btc_miners_revenue  \
# 0             0.0                 244                 0.0
# 1             0.0                 235                 0.0
# 2             0.0                 183                 0.0
# 3             0.0                 224                 0.0
# 4             0.0                 218                 0.0
# 5             0.0                 261                 0.0
# 6             0.0                 252                 0.0
# 7             0.0                 196                 0.0
# 8             0.0                 150                 0.0
# 9             0.0                 176                 0.0
#
#    btc_cost_per_transaction  btc_difficulty  btc_hash_rate  \
# 0                       0.0        2.527738       0.000029
# 1                       0.0        2.527738       0.000029
# 2                       0.0        2.527738       0.000023
# 3                       0.0        2.527738       0.000028
# ...

# %%
subset_dataset.isnull().values.any()
# Out:
# False

# %%
x = subset_dataset.iloc[:, :-1] ## importing everything except last column
y = subset_dataset.iloc[:, -1]  ## importing only the last column

# %%
print(x)
# Out:
#       btc_market_cap  btc_n_transactions  btc_miners_revenue  \
# 0       0.000000e+00                 244                0.00
# 1       0.000000e+00                 235                0.00
# 2       0.000000e+00                 183                0.00
# 3       0.000000e+00                 224                0.00
# 4       0.000000e+00                 218                0.00
# ...              ...                 ...                 ...
# 2901    1.940000e+11              193578         23654604.11
# 2902    1.980000e+11              213446         24143236.92
# 2903    1.890000e+11              232176         21651636.81
# 2904    1.710000e+11              236609         22124873.97
# 2905    1.700000e+11              204276         15840583.36
#
#       btc_cost_per_transaction  btc_difficulty  btc_hash_rate  \
# 0                     0.000000    2.527738e+00   2.920000e-05
# 1                     0.000000    2.527738e+00   2.880000e-05
# ...

# %%
print(y)
# Out:
# 0           0.00000
# 1           0.00000
# 2           0.00000
# 3           0.00000
# 4           0.00000
#            ...
# 2901    11524.77667
# 2902    11765.71000
# 2903    11212.65500
# 2904    10184.06167
# 2905    10125.01333
# Name: btc_market_price, Length: 2906, dtype: float64

# %%
## creating train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
## fitting to train model
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = regressor.predict(x_test)
print(y_predict)
# Out:
# [ 1.53617495e+01  2.72476747e+02  1.09107599e+02  4.64444266e+02
#   4.17057843e+00  4.78743374e+01  2.15756955e+00  2.48371299e+03
#   7.95863138e+02  1.18770842e+01  1.02165624e+01 -3.70702064e+00
#   5.46084930e+03  6.53446640e+00 -6.89938387e+00  1.25645787e+01
#   2.48431071e+01  3.00776872e+02  8.82716997e+02  7.27869964e+01
#  -1.27052102e+01  8.26367735e+01  2.60604435e+02  1.04478740e+00
#  -6.92224957e-02 -1.27007453e+01  7.85576935e+00  8.98430496e+00
#   6.46730865e+02 -7.79153323e+00  1.17997814e+01  1.17467740e+01
#   4.74875245e+01  7.47276282e+00  2.44876719e+02  1.05689176e+03
#   4.15330017e+02  4.35626407e+02  2.46423017e+02  1.15101869e+02
#   6.01841341e+02  1.24309708e+02  1.63039488e+01  5.35105710e+02
#   2.28294813e+01  6.49005659e+02  3.23130322e+02  2.81761147e+02
#   3.72918361e+00  5.21632442e+02 -1.26890195e+01  4.57379894e+03
#   1.71884561e+04  4.16926617e+01  6.29830129e+00  6.23723390e+02
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_predict, y_test)  ## mean square error value - 425.7471758411076
# Out:
# 425.7471758411076

# %%
print(y_test)
# Out:
# 582       5.83001
# 2001    265.85000
# 1259    101.89998
# 2129    453.39000
# 667       3.23000
#           ...
# 206       0.06200
# 97        0.00000
# 1260    104.95555
# 2427    617.54825
# 2518    894.18025
# Name: btc_market_price, Length: 969, dtype: float64

# %%
print(y_predict)
# Out:
# [ 1.54e+01  2.72e+02  1.09e+02  4.64e+02  4.17e+00  4.79e+01  2.16e+00
#   2.48e+03  7.96e+02  1.19e+01  1.02e+01 -3.71e+00  5.46e+03  6.53e+00
#  -6.90e+00  1.26e+01  2.48e+01  3.01e+02  8.83e+02  7.28e+01 -1.27e+01
#   8.26e+01  2.61e+02  1.04e+00 -6.92e-02 -1.27e+01  7.86e+00  8.98e+00
#   6.47e+02 -7.79e+00  1.18e+01  1.17e+01  4.75e+01  7.47e+00  2.45e+02
#   1.06e+03  4.15e+02  4.36e+02  2.46e+02  1.15e+02  6.02e+02  1.24e+02
#   1.63e+01  5.35e+02  2.28e+01  6.49e+02  3.23e+02  2.82e+02  3.73e+00
#   5.22e+02 -1.27e+01  4.57e+03  1.72e+04  4.17e+01  6.30e+00  6.24e+02
#   3.65e+01  1.53e+04  1.32e+01  1.15e+02  7.99e+02  2.43e+03  2.71e+03
#   4.72e+02 -1.27e+01  5.40e+02  1.84e+00  1.24e+02  3.73e+02  5.55e-01
#   3.90e+02  2.01e+01  3.17e+02 -1.27e+01 -1.27e+01  1.41e+01  4.45e+02
#   2.47e+02  1.10e+02  2.38e+02  1.49e+01  6.51e+02  3.45e+00  2.92e+01
#   6.52e+03  9.29e+02  1.50e+01  3.40e+02  1.41e+01  6.16e+02  1.73e+01
# ...
