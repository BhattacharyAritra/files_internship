# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ari_b\\Documents\\Winternship by Widhya\\Week 3 Assignments'

# %%
dataset = pd.read_csv("covid19_analysis.csv")

# %%
dataset
# Out:
#      Sno        Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30-01-2020               Kerala                        1
# 1      2  31-01-2020               Kerala                        1
# 2      3  01-02-2020               Kerala                        2
# 3      4  02-02-2020               Kerala                        3
# 4      5  03-02-2020               Kerala                        3
# ..   ...         ...                  ...                      ...
# 265  266  21-03-2020    Jammu and Kashmir                        4
# 266  267  21-03-2020               Ladakh                       13
# 267  268  21-03-2020        Uttar Pradesh                       23
# 268  269  21-03-2020          Uttarakhand                        3
# 269  270  21-03-2020          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# ...

# %%
dataset.head(10)
# Out:
#    Sno        Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30-01-2020               Kerala                        1
# 1    2  31-01-2020               Kerala                        1
# 2    3  01-02-2020               Kerala                        2
# 3    4  02-02-2020               Kerala                        3
# 4    5  03-02-2020               Kerala                        3
# 5    6  04-02-2020               Kerala                        3
# 6    7  05-02-2020               Kerala                        3
# 7    8  06-02-2020               Kerala                        3
# 8    9  07-02-2020               Kerala                        3
# 9   10  08-02-2020               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# ...

# %%
len(dataset)
# Out:
# 270

# %%
dataset.columns
# Out:
# Index(['Sno', 'Date', 'State/UnionTerritory', 'ConfirmedIndianNational',
#        'ConfirmedForeignNational', 'Cured', 'Deaths'],
#       dtype='object')

# %%
dataset.Date.dtypes
# Out:
# dtype('O')

# %%
dataset['Date'] = pd.to_datetime(dataset.Date)

# %%
dataset.dtypes
# Out:
# Sno                                  int64
# Date                        datetime64[ns]
# State/UnionTerritory                object
# ConfirmedIndianNational              int64
# ConfirmedForeignNational             int64
# Cured                                int64
# Deaths                               int64
# dtype: object

# %%
dataset.head()
# Out:
#    Sno       Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1 2020-01-30               Kerala                        1
# 1    2 2020-01-31               Kerala                        1
# 2    3 2020-01-02               Kerala                        2
# 3    4 2020-02-02               Kerala                        3
# 4    5 2020-03-02               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
indian_data_by_date = dataset.groupby("Date")[['Date','ConfirmedIndianNational', 'State/UnionTerritory','Cured', 'Deaths']]

# %%
indian_data_by_date.head()
# Out:
#           Date  ConfirmedIndianNational State/UnionTerritory  Cured  Deaths
# 0   2020-01-30                        1               Kerala      0       0
# 1   2020-01-31                        1               Kerala      0       0
# 2   2020-01-02                        2               Kerala      0       0
# 3   2020-02-02                        3               Kerala      0       0
# 4   2020-03-02                        3               Kerala      0       0
# ..         ...                      ...                  ...    ...     ...
# 248 2020-03-21                        3       Andhra Pradesh      0       0
# 249 2020-03-21                        1         Chhattisgarh      0       0
# 250 2020-03-21                       25                Delhi      5       1
# 251 2020-03-21                        7              Gujarat      0       0
# 252 2020-03-21                        3              Haryana      0       0
#
# [129 rows x 5 columns]

# %%
len(indian_data_by_date)
# Out:
# 52

# %%
foreign_data_by_date = dataset.groupby("Date")[['Date','ConfirmedForeignNational', 'State/UnionTerritory','Cured', 'Deaths']]

# %%
foreign_data_by_date.head(10)
# Out:
#           Date  ConfirmedForeignNational State/UnionTerritory  Cured  Deaths
# 0   2020-01-30                         0               Kerala      0       0
# 1   2020-01-31                         0               Kerala      0       0
# 2   2020-01-02                         0               Kerala      0       0
# 3   2020-02-02                         0               Kerala      0       0
# 4   2020-03-02                         0               Kerala      0       0
# ..         ...                       ...                  ...    ...     ...
# 253 2020-03-21                         0     Himachal Pradesh      0       0
# 254 2020-03-21                         0            Karnataka      1       1
# 255 2020-03-21                         7               Kerala      3       0
# 256 2020-03-21                         0       Madhya Pradesh      0       0
# 257 2020-03-21                         3          Maharashtra      0       1
#
# [203 rows x 5 columns]

# %%
len(foreign_data_by_date)
# Out:
# 52

# %%
indian_data_by_date.dtypes
# Out:
#                       Date ConfirmedIndianNational State/UnionTerritory  \
# Date
# 2020-01-02  datetime64[ns]                   int64               object
# 2020-01-03  datetime64[ns]                   int64               object
# 2020-01-30  datetime64[ns]                   int64               object
# 2020-01-31  datetime64[ns]                   int64               object
# 2020-02-02  datetime64[ns]                   int64               object
# 2020-02-03  datetime64[ns]                   int64               object
# 2020-02-13  datetime64[ns]                   int64               object
# 2020-02-14  datetime64[ns]                   int64               object
# 2020-02-15  datetime64[ns]                   int64               object
# 2020-02-16  datetime64[ns]                   int64               object
# 2020-02-17  datetime64[ns]                   int64               object
# 2020-02-18  datetime64[ns]                   int64               object
# ...

# %%
dataset.dtypes
# Out:
# Sno                                  int64
# Date                        datetime64[ns]
# State/UnionTerritory                object
# ConfirmedIndianNational              int64
# ConfirmedForeignNational             int64
# Cured                                int64
# Deaths                               int64
# dtype: object
